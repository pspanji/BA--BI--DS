# %% [markdown]
# <a href="https://colab.research.google.com/github/pspanji/BA--BI--DS/blob/main/Key%20value%20pairs_products.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'customer_id': [1, 1, 2, 2],'Product_id': [123,111,213,987],'Recomendtions': [[66,555,111,98],[213,12,503,21],[321,98712,1212,3434],[4545,98711,4567]],'date_values' : ['2020-05-10', '2020-05-10', '2020-05-10', '2020-05-10']}
data
df = pd.DataFrame(data)
df
# Out:
#    customer_id  Product_id             Recomendtions date_values
# 0            1         123        [66, 555, 111, 98]  2020-05-10
# 1            1         111        [213, 12, 503, 21]  2020-05-10
# 2            2         213  [321, 98712, 1212, 3434]  2020-05-10
# 3            2         987       [4545, 98711, 4567]  2020-05-10

# %%
df = df.explode('Recomendtions', ignore_index=True)
df
# Out:
#     customer_id  Product_id Recomendtions date_values
# 0             1         123            66  2020-05-10
# 1             1         123           555  2020-05-10
# 2             1         123           111  2020-05-10
# 3             1         123            98  2020-05-10
# 4             1         111           213  2020-05-10
# 5             1         111            12  2020-05-10
# 6             1         111           503  2020-05-10
# 7             1         111            21  2020-05-10
# 8             2         213           321  2020-05-10
# 9             2         213         98712  2020-05-10
# 10            2         213          1212  2020-05-10
# 11            2         213          3434  2020-05-10
# 12            2         987          4545  2020-05-10
# 13            2         987         98711  2020-05-10
# 14            2         987          4567  2020-05-10
